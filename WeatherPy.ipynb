# %%
import random
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
#np.random.uniform(-90.000,90.000,size=50)
#%timeit np.random.uniform(-90.000, 90.000, size=1500)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=100)
lngs = np.random.uniform(low=-180.000, high=180.000, size=100)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 84

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gubkinskiy
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | flinders
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | borba
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | saint-augustin
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | olavarria
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | awjilah
# Processing Record 18 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 1 | pacific grove
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | plettenberg bay
# Processing Record 22 of Set 1 | atlantic beach
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | kysyl-syr
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | hambantota
# Processing Record 28 of Set 1 | rognan
# Processing Record 29 of Set 1 | deputatskiy
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | comodoro rivadavia
# Processing Record 32 of Set 1 | la ronge
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | santa rosa
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | bandarbeyla
# Processing Record 38 of Set 1 | nizwa
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | tilichiki
# Processing Record 44 of Set 1 | les cayes
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | severnyy
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | pedasi
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 2 | vossevangen
# Processing Record 9 of Set 2 | sandusky
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | lucapa
# Processing Record 12 of Set 2 | northam
# Processing Record 13 of Set 2 | bubaque
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | ayagoz
# Processing Record 17 of Set 2 | kropotkin
# Processing Record 18 of Set 2 | mosquera
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | riyadh
# Processing Record 21 of Set 2 | padang
# Processing Record 22 of Set 2 | taywarah
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | ye
# City not found. Skipping...
# Processing Record 26 of Set 2 | manzanillo
# Processing Record 27 of Set 2 | adre
# Processing Record 28 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | praia da vitoria
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | vaini
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city
# Out:
# [{'City': 'Gubkinskiy',
#   'Lat': 64.43,
#   'Lng': 76.5,
#   'Max Temp': 30.16,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.24,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:41:28'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 23.04,
#   'Country': 'US',
#   'Date': '2020-02-20 00:37:19'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 78.01,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 16.64,
#   'Country': 'AU',
#   'Date': '2020-02-20 00:37:25'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 67.39,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 3.62,
#   'Country': 'BR',
#   'Date': '2020-02-20 00:37:43'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': -11.92,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.06,
#   'Country': 'GL',
#   'Date': '2020-02-20 00:37:37'},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 79,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': '2020-02-20 00:38:16'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 30.2,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': '2020-02-20 00:35:02'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 78.01,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-02-20 00:36:57'},
#  {'City': 'Borba',
#   'Lat': -4.39,
#   'Lng': -59.59,
#   'Max Temp': 75.49,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'BR',
#   'Date': '2020-02-20 00:41:30'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'ES',
#   'Date': '2020-02-20 00:37:41'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 24.58,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 19.08,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:38:05'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'AR',
#   'Date': '2020-02-20 00:36:00'},
#  {'City': 'Olavarria',
#   'Lat': -36.89,
#   'Lng': -60.32,
#   'Max Temp': 63,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Date': '2020-02-20 00:41:31'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 66.49,
#   'Humidity': 55,
#   'Cloudiness': 92,
#   'Wind Speed': 7.11,
#   'Country': 'NZ',
#   'Date': '2020-02-20 00:37:32'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 19.2,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 15.82,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:37:39'},
#  {'City': 'Awjilah',
#   'Lat': 29.11,
#   'Lng': 21.29,
#   'Max Temp': 54,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 6.35,
#   'Country': 'LY',
#   'Date': '2020-02-20 00:41:31'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 69.01,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-02-20 00:41:31'},
#  {'City': 'San Patricio',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'MX',
#   'Date': '2020-02-20 00:38:36'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.05,
#   'Lng': 23.37,
#   'Max Temp': 75.38,
#   'Humidity': 56,
#   'Cloudiness': 82,
#   'Wind Speed': 10.69,
#   'Country': 'ZA',
#   'Date': '2020-02-20 00:41:33'},
#  {'City': 'Atlantic Beach',
#   'Lat': 30.33,
#   'Lng': -81.4,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': '2020-02-20 00:37:53'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 78.46,
#   'Humidity': 80,
#   'Cloudiness': 3,
#   'Wind Speed': 13.33,
#   'Country': 'PF',
#   'Date': '2020-02-20 00:37:25'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 26.01,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-02-20 00:37:22'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': -0.9,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:41:33'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 37.99,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-02-20 00:37:43'},
#  {'City': 'Hambantota',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 78.82,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 23.76,
#   'Country': 'LK',
#   'Date': '2020-02-20 00:38:14'},
#  {'City': 'Rognan',
#   'Lat': 67.1,
#   'Lng': 15.39,
#   'Max Temp': 24.01,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 21.92,
#   'Country': 'NO',
#   'Date': '2020-02-20 00:41:35'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -6.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:38:17'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 21.92,
#   'Country': 'PE',
#   'Date': '2020-02-20 00:41:35'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 62.6,
#   'Humidity': 45,
#   'Cloudiness': 81,
#   'Wind Speed': 6.93,
#   'Country': 'AR',
#   'Date': '2020-02-20 00:36:12'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 15.8,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:41:35'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 66.16,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 13.65,
#   'Country': 'MX',
#   'Date': '2020-02-20 00:37:47'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 62.01,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 11.01,
#   'Country': 'NZ',
#   'Date': '2020-02-20 00:37:25'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 80.01,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'PH',
#   'Date': '2020-02-20 00:41:36'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 8.6,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:37:25'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 76.77,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 9.31,
#   'Country': 'SO',
#   'Date': '2020-02-20 00:38:03'},
#  {'City': 'Nizwa',
#   'Lat': 22.93,
#   'Lng': 57.53,
#   'Max Temp': 61.88,
#   'Humidity': 41,
#   'Cloudiness': 58,
#   'Wind Speed': 0.72,
#   'Country': 'OM',
#   'Date': '2020-02-20 00:38:10'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-02-20 00:38:13'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 67.57,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'NZ',
#   'Date': '2020-02-20 00:37:22'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'CK',
#   'Date': '2020-02-20 00:37:30'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'EC',
#   'Date': '2020-02-20 00:37:36'},
#  {'City': 'Tilichiki',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': -14.13,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:37:46'},
#  {'City': 'Les Cayes',
#   'Lat': 18.2,
#   'Lng': -73.75,
#   'Max Temp': 80.69,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 13.58,
#   'Country': 'HT',
#   'Date': '2020-02-20 00:41:37'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 65,
#   'Wind Speed': 2.24,
#   'Country': 'ZA',
#   'Date': '2020-02-20 00:37:59'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 34,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 27.51,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:38:09'},
#  {'City': 'Severnyy',
#   'Lat': 50.68,
#   'Lng': 36.55,
#   'Max Temp': 30.2,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:41:37'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.74,
#   'Country': 'MU',
#   'Date': '2020-02-20 00:37:53'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 82.08,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 17.38,
#   'Country': 'PF',
#   'Date': '2020-02-20 00:37:45'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 66,
#   'Humidity': 96,
#   'Cloudiness': 3,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Date': '2020-02-20 00:37:33'},
#  {'City': 'Pedasi',
#   'Lat': 7.53,
#   'Lng': -80.03,
#   'Max Temp': 82,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind Speed': 20.22,
#   'Country': 'PA',
#   'Date': '2020-02-20 00:41:38'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 6.8,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:37:49'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': -7.98,
#   'Humidity': 99,
#   'Cloudiness': 0,
#   'Wind Speed': 6.76,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:37:29'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 63,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'AU',
#   'Date': '2020-02-20 00:37:27'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'MY',
#   'Date': '2020-02-20 00:38:23'},
#  {'City': 'Vossevangen',
#   'Lat': 60.62,
#   'Lng': 6.42,
#   'Max Temp': 37.99,
#   'Humidity': 88,
#   'Cloudiness': 50,
#   'Wind Speed': 1.01,
#   'Country': 'NO',
#   'Date': '2020-02-20 00:40:47'},
#  {'City': 'Sandusky',
#   'Lat': 41.35,
#   'Lng': -83.13,
#   'Max Temp': 30.99,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 6.46,
#   'Country': 'US',
#   'Date': '2020-02-20 00:41:30'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 51.64,
#   'Humidity': 73,
#   'Cloudiness': 34,
#   'Wind Speed': 20.04,
#   'Country': 'PT',
#   'Date': '2020-02-20 00:38:18'},
#  {'City': 'Lucapa',
#   'Lat': -8.42,
#   'Lng': 20.74,
#   'Max Temp': 66.87,
#   'Humidity': 96,
#   'Cloudiness': 69,
#   'Wind Speed': 2.57,
#   'Country': 'AO',
#   'Date': '2020-02-20 00:41:39'},
#  {'City': 'Northam',
#   'Lat': 51.03,
#   'Lng': -4.22,
#   'Max Temp': 50,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'GB',
#   'Date': '2020-02-20 00:41:40'},
#  {'City': 'Bubaque',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 79.03,
#   'Humidity': 74,
#   'Cloudiness': 19,
#   'Wind Speed': 16.2,
#   'Country': 'GW',
#   'Date': '2020-02-20 00:38:32'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': -4.65,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.78,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:37:47'},
#  {'City': 'Namibe',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 74.23,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Country': 'AO',
#   'Date': '2020-02-20 00:38:31'},
#  {'City': 'Ayagoz',
#   'Lat': 47.97,
#   'Lng': 80.44,
#   'Max Temp': 13.51,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.41,
#   'Country': 'KZ',
#   'Date': '2020-02-20 00:41:06'},
#  {'City': 'Kropotkin',
#   'Lat': 45.44,
#   'Lng': 40.58,
#   'Max Temp': 39.97,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:41:40'},
#  {'City': 'Mosquera',
#   'Lat': 4.71,
#   'Lng': -74.23,
#   'Max Temp': 62.6,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'CO',
#   'Date': '2020-02-20 00:40:31'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 83.34,
#   'Humidity': 71,
#   'Cloudiness': 27,
#   'Wind Speed': 7.85,
#   'Country': 'PG',
#   'Date': '2020-02-20 00:37:30'},
#  {'City': 'Riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 71.6,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'SA',
#   'Date': '2020-02-20 00:40:18'},
#  {'City': 'Padang',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 69.55,
#   'Humidity': 82,
#   'Cloudiness': 69,
#   'Wind Speed': 8.28,
#   'Country': 'ID',
#   'Date': '2020-02-20 00:41:41'},
#  {'City': 'Taywarah',
#   'Lat': 33.35,
#   'Lng': 64.42,
#   'Max Temp': 10.53,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 6.49,
#   'Country': 'AF',
#   'Date': '2020-02-20 00:41:41'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 68.67,
#   'Humidity': 85,
#   'Cloudiness': 2,
#   'Wind Speed': 6.2,
#   'Country': 'UY',
#   'Date': '2020-02-20 00:37:31'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 73.72,
#   'Humidity': 83,
#   'Cloudiness': 83,
#   'Wind Speed': 18.79,
#   'Country': 'ZA',
#   'Date': '2020-02-20 00:37:35'},
#  {'City': 'Manzanillo',
#   'Lat': 20.34,
#   'Lng': -77.12,
#   'Max Temp': 81.23,
#   'Humidity': 60,
#   'Cloudiness': 70,
#   'Wind Speed': 5.17,
#   'Country': 'CU',
#   'Date': '2020-02-20 00:41:42'},
#  {'City': 'Adre',
#   'Lat': 13.47,
#   'Lng': 22.2,
#   'Max Temp': 66.54,
#   'Humidity': 25,
#   'Cloudiness': 67,
#   'Wind Speed': 18.88,
#   'Country': 'TD',
#   'Date': '2020-02-20 00:41:42'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 10.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': '2020-02-20 00:37:34'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 55.4,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 25.05,
#   'Country': 'PT',
#   'Date': '2020-02-20 00:41:42'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 19.99,
#   'Humidity': 85,
#   'Cloudiness': 41,
#   'Wind Speed': 10.38,
#   'Country': 'RU',
#   'Date': '2020-02-20 00:38:01'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 69.01,
#   'Humidity': 93,
#   'Cloudiness': 5,
#   'Wind Speed': 5.35,
#   'Country': 'ZA',
#   'Date': '2020-02-20 00:37:38'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'TO',
#   'Date': '2020-02-20 00:37:36'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(2)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Gubkinskiy  64.43   76.50     30.16        95         100       13.24
# 1       Kapaa  22.08 -159.32     80.60        88          90       23.04
#
#   Country                 Date
# 0      RU  2020-02-20 00:41:28
# 1      US  2020-02-20 00:37:19

# %%
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(2)
# Out:
#          City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0  Gubkinskiy      RU  2020-02-20 00:41:28  64.43   76.50     30.16        95
# 1       Kapaa      US  2020-02-20 00:37:19  22.08 -159.32     80.60        88
#
#    Cloudiness  Wind Speed
# 0         100       13.24
# 1          90       23.04

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
